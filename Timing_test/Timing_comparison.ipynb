# %%
import scarlet
import galsim
from astropy import wcs as WCS
from mr_tools import galsim_compare_tools as gct
import time
import pickle

# %% [markdown]
# This notebook times the execution of the galsim and scarlet resampling routines

# %%
# %pylab inline
data_dir='/Users/remy/Desktop/LSST_Project/GalSim/examples/data'
#Reference catalog for simulations
cat = galsim.COSMOSCatalog(dir=data_dir, file_name = 'real_galaxy_catalog_23.5_example.fits')
#Survey dictionaries
HST, EUCLID, WFIRST, HSC, RUBIN = gct.load_surveys()
#CHannels
channel_hr = ['hr']
channel_lr = ['lr']
channels = channel_lr+channel_hr

matplotlib.rc('image', cmap='gist_stern')
matplotlib.rc('image', interpolation='none')
matplotlib.rc('xtick', labelsize=20)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Shapes tested for timing
shapes = [20, 30, 50, 70, 100, 150, 200]
#List of surveys
surveys = [HST, EUCLID, WFIRST, HSC, RUBIN]
#Size of the psf (pixels on-a-side)
npsf = 41
# Dictionary for storing results
structure = {'survey_hr':[], 'survey_lr': [], 'n_hr': [], 'n_lr': [], 's_mean': [], 's_std': [], 
             'g_mean': [], 'g_std': []}

#Timing for all combinations of high-low resolution images and all shapes in `shapes`
for nhr in shapes:
    for k, surveyhr in enumerate(surveys):
        print(nhr, surveyhr)
        for g, surveylr in enumerate(surveys[k+1:]):
            print(surveylr)
            # Making sure that the lr image spans roughly the same area on the sky as the hr image.
            nlr = int(nhr*surveyhr['pixel']/surveylr['pixel'])
            
            # Make simulations, picks a galaxy at random
            r = np.random.rand(1)*90
            data_hr, data_lr, psf_hr, psf_lr, angle = gct.mk_sim(int(r), surveyhr, surveylr, (nhr, nhr), 
                                                                 (nlr, nlr), npsf, cat)

            # scarlet setup
            obs_lr, obs_hr = gct.setup_scarlet(data_hr, data_lr, psf_hr, psf_lr, channels)
    
            # Galsim setup:
            ## GSO from psf_hr for galsim
            psf_hr_galsim = galsim.InterpolatedImage(galsim.Image(psf_hr[0]), 
                                               scale = surveyhr['pixel'], use_true_center = False)
            ## deconvolution kernel for diff kernel
            deconv = galsim.Deconvolve(psf_hr_galsim)
            ## Interpolation of low resolution psf at high resolution
            psf_lr_hr = galsim.InterpolatedImage(galsim.Image(psf_lr[0]), 
                                               scale = surveylr['pixel'], use_true_center = False)
            ## Difference kernel from galsim
            diff_gal = galsim.Convolve(deconv, psf_lr_hr)
        
            # Scarlet timing
            t_s = %timeit -n 100 -o obs_lr.render(data_hr.array[None,:,:])
            s_mean = np.array(t_s.all_runs).mean()/t_s.loops
            s_std = np.array(t_s.all_runs).std()/t_s.loops 
            # Galsim timing
            t_g = %timeit -n 100 -o gct.interp_galsim(data_hr, data_lr, diff_gal, angle, surveyhr['pixel'], surveylr['pixel'])
            g_mean = np.array(t_g.all_runs).mean()/t_g.loops 
            g_std = np.array(t_g.all_runs).std()/t_g.loops
            
            #Storage
            structure['survey_hr'].append(surveyhr) 
            structure['survey_lr'].append(surveylr) 
            structure['n_hr'].append(nhr) 
            structure['n_lr'].append(nlr)
            structure['s_mean'].append(s_mean)
            structure['s_std'].append(s_std)
            structure['g_mean'].append(g_mean) 
            structure['g_std'].append(g_std)
            
#Saving results
import pickle
afile = open('Timings_npsf='+str(npsf)+'.pkl', 'wb')
pickle.dump(structure, afile)
afile.close()
# Out:
# 20 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 1.24 ms ± 39.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.72 ms ± 150 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 1.14 ms ± 51.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.62 ms ± 116 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 994 µs ± 32.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.49 ms ± 151 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 744 µs ± 10.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.42 ms ± 144 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 1.91 ms ± 150 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.89 ms ± 121 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 1.21 ms ± 88.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.64 ms ± 146 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 1.14 ms ± 111 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.69 ms ± 84.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 1.45 ms ± 97.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.64 ms ± 142 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 1.22 ms ± 56.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.65 ms ± 100 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 1.81 ms ± 141 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.26 ms ± 227 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 30 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 2.22 ms ± 155 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.24 ms ± 291 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 2.06 ms ± 190 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.09 ms ± 258 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 1.65 ms ± 99.5 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.73 ms ± 131 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 1.57 ms ± 75.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.87 ms ± 367 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 3.33 ms ± 240 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.11 ms ± 334 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 2.91 ms ± 269 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.92 ms ± 320 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 2.6 ms ± 192 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.81 ms ± 287 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 3.21 ms ± 257 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.93 ms ± 326 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 2.62 ms ± 165 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 4.92 ms ± 325 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 3.27 ms ± 410 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.02 ms ± 433 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 50 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 7.19 ms ± 478 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.99 ms ± 398 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 5.25 ms ± 342 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.45 ms ± 697 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 3.76 ms ± 272 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.71 ms ± 360 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 3.53 ms ± 347 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 5.81 ms ± 342 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 50 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 12.2 ms ± 526 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.38 ms ± 586 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 9.51 ms ± 426 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.18 ms ± 317 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 5.95 ms ± 321 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 6.92 ms ± 96.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 50 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 9.82 ms ± 343 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.86 ms ± 154 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 8.53 ms ± 192 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 7.7 ms ± 100 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 50 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 11.4 ms ± 360 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 8.06 ms ± 205 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 50 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 70 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 19 ms ± 682 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.4 ms ± 637 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 16.9 ms ± 1.11 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 10.3 ms ± 483 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 9.07 ms ± 389 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.04 ms ± 372 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 7.14 ms ± 297 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 9.95 ms ± 223 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 70 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 27.9 ms ± 2.55 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12.1 ms ± 629 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 22.2 ms ± 568 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12.4 ms ± 700 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 19.5 ms ± 1.24 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 11.7 ms ± 633 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 70 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 27.4 ms ± 1.35 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12.3 ms ± 608 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 23.9 ms ± 409 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 12.3 ms ± 444 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 70 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 33.9 ms ± 1.43 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 14.8 ms ± 676 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 70 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 100 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 53 ms ± 2.92 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20.6 ms ± 780 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 47 ms ± 2.08 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.4 ms ± 424 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 33.3 ms ± 1.06 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15.6 ms ± 313 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 30.4 ms ± 2.22 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17.2 ms ± 421 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 100 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 93.6 ms ± 6.27 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 19.3 ms ± 736 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 53.5 ms ± 1.82 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 17 ms ± 693 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 46.6 ms ± 3.19 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 18.4 ms ± 368 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 100 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 67.9 ms ± 3.21 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 16.1 ms ± 434 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 52.2 ms ± 1.53 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 20 ms ± 762 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 100 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 78.3 ms ± 6.1 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 15 ms ± 480 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 100 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 150 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 165 ms ± 15.1 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 28.2 ms ± 849 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 142 ms ± 10.2 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 27 ms ± 2.31 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 105 ms ± 16.3 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30.1 ms ± 3.27 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 82.2 ms ± 9.95 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 32 ms ± 1.99 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 150 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 239 ms ± 39.5 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 41.7 ms ± 4.38 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 209 ms ± 34.8 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 28.2 ms ± 1.51 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 166 ms ± 14.1 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 30.2 ms ± 1.52 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 150 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 198 ms ± 16 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 36.2 ms ± 4.09 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 241 ms ± 34.5 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 40.4 ms ± 2.46 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 150 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 354 ms ± 37 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 40.7 ms ± 2.22 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 150 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 200 {'name': 'HST', 'pixel': 0.06, 'psf': 0.074}
# {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# 453 ms ± 41.9 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 63.4 ms ± 3.1 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 628 ms ± 165 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 82.4 ms ± 6.12 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 395 ms ± 44.7 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 89.1 ms ± 11.9 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 288 ms ± 53.2 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 65.7 ms ± 5.24 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 200 {'name': 'EUCLID', 'pixel': 0.1, 'psf': 0.16}
# {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# 833 ms ± 172 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 66.6 ms ± 4.78 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 295 ms ± 12.8 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 45.6 ms ± 1.41 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 264 ms ± 9.71 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 44.4 ms ± 5.05 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 200 {'name': 'ROMAN', 'pixel': 0.11, 'psf': 0.18589999999999998}
# {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# 537 ms ± 35.9 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 61.9 ms ± 4.67 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 270 ms ± 21.7 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 72.2 ms ± 3.91 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 200 {'name': 'HSC', 'pixel': 0.167, 'psf': 0.62}
# {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}
# 564 ms ± 39.7 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 39.7 ms ± 1.31 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 200 {'name': 'RUBIN', 'pixel': 0.2, 'psf': 0.7}

# %%
structure = pickle.load(open('Timings_npsf='+str(npsf)+'.pkl', 'rb'))

#Reading results
n_hrs = np.array(structure['n_hr'])
n_lrs = np.array(structure['n_lr'])
s_mean = (np.array(structure['s_mean']))
s_std = np.array(structure['s_std'])
g_mean = np.array(structure['g_mean'])
g_std = np.array(structure['g_std'])

matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
plt.close()
#Plotting results. Mean timing of resampling runs as a function of N
plt.figure(0, figsize = (15,15))
plt.subplots(figsize=(10, 6))
#ax2.errorbar(n_lrs, s_mean, yerr = s_std, capsize = 2, fmt = 'o', label = 'scarlet')
sc1 = plt.scatter(n_hrs, s_mean,c = n_lrs, marker = 'o', cmap = 'winter')
#ax2.errorbar(n_lrs, g_mean, yerr = g_std, capsize = 2, fmt = 's', label = 'galsim')
sc2 = plt.scatter(n_hrs, g_mean,c = n_lrs, marker = 's', cmap = 'copper')
plt.yscale('log')
cbar = plt.colorbar(sc1)
plt.colorbar(sc2)
cbar.set_label('M (# of pixels)', rotation=270, labelpad = 20, fontsize = 20)
# Adding plotting parameters
plt.title('Mean timing of resampling runs', fontsize=20)
plt.xlabel('N (# of pixels)', fontsize=20)
plt.ylabel('t (s)', fontsize=20)
plt.ylim([0.001,1])
plt.show()

#Plotting results. Mean timing of resampling runs as a function of M
plt.figure(1, figsize = (15,15))
plt.subplots(figsize=(10, 6))
#ax2.errorbar(n_lrs, s_mean, yerr = s_std, capsize = 2, fmt = 'o', label = 'scarlet')
sc1 = plt.scatter(n_lrs, s_mean,c = n_hrs, marker = 'o', cmap = 'winter')
#ax2.errorbar(n_lrs, g_mean, yerr = g_std, capsize = 2, fmt = 's', label = 'galsim')
sc2 = plt.scatter(n_lrs, g_mean,c = n_hrs, marker = 's', cmap = 'copper')
plt.yscale('log')
cbar = plt.colorbar(sc1)
plt.colorbar(sc2)
cbar.set_label('N (# ofpixels)', rotation=270, fontsize = 20, labelpad = 20)
# Adding plotting parameters
plt.title('Mean timing of resampling runs', fontsize=20)
plt.xlabel('M (# of pixels)', fontsize=20)
plt.ylabel('t (s)', fontsize=20)
plt.savefig('galsim_scarlet_timing.png')
plt.ylim(0.001,1)
plt.show()

# %%
#Timing ratios as a function of M
plt.figure(2, figsize = (15,15))
fig2, ax2 = plt.subplots(figsize=(10, 6))
sc1 = ax2.scatter(n_lrs, s_mean/g_mean,c = n_hrs, marker = 'o', cmap = 'winter')
#plot((np.arange(5,200)), (np.arange(5,200))/30, label = 'M/30')
plt.legend()
yscale('log')
cbar = colorbar(sc1)
plot([0,220], [1,1], '--k')
cbar.set_label('N (# of pixels)', rotation=270, fontsize = 20, labelpad = 20)
# Adding plotting parameters
ax2.set_title('Timing ratios of resampling runs', fontsize=20)
ax2.set_xlabel('M (# of pixels)', fontsize=20)
ax2.set_ylabel('time ratios', fontsize=20)
savefig('galsim_scarlet_ratio.png')
show()

#Timing ratios as a function of N
figure(3, figsize = (15,15))
fig2, ax2 = plt.subplots(figsize=(10, 6))
sc1 = ax2.scatter(n_hrs, s_mean/g_mean,c = n_lrs, marker = 'o', cmap = 'winter')
yscale('log')
colorbar(sc1)
plot([0,220], [1,1], '--k')
# Adding plotting parameters
ax2.set_title('Timing ratios of resampling runs', fontsize=14)
plt.legend()
ax2.set_xlabel('N (# of pixels)', fontsize=20)
ax2.set_ylabel('time ratios', fontsize=20)
show()

#Colour representation of the colour ratios
figure(4, figsize = (15,15))
fig2, ax2 = plt.subplots(figsize=(10, 6))
sc1 = ax2.scatter(n_hrs, n_lrs,c = np.log10(s_mean/g_mean), marker = 'o', cmap = 'seismic')

colorbar(sc1)
# Adding plotting parameters
ax2.set_title('Timing ratios of resampling runs', fontsize=14)
ax2.set_xlabel('N (# of pixels)', fontsize=20)
ax2.set_ylabel('M (# of pixels)', fontsize=20)
show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
